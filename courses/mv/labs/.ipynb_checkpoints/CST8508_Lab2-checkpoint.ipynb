# %%
"""
CST8508 Machine Vision - Lab 2: Image Processing with OpenCV
Author: Peng Wang
Student Number: 041107730

Objective:
To provide students with practical experience in basic image processing techniques 
using OpenCV, including:
1. Histogram calculation and visualization.
2. Global and adaptive thresholding methods.
3. Fundamental morphological operations (Erosion, Dilation, Opening, Closing).
"""

# %%
# 导入 OpenCV 库，这是计算机视觉处理的核心工具
# Import OpenCV library, the core tool for computer vision processing
import cv2

# 导入 NumPy 库，用于高效的数值计算和数组操作
# Import NumPy library for efficient numerical computation and array manipulation
import numpy as np

# 从 Matplotlib 导入绘图模块，用于将图像和图表渲染到界面上
# Import plotting module from Matplotlib for rendering images and charts
from matplotlib import pyplot as plt

# %%
# 设定样图的本地文件路径
# Set the local file path for the sample image
image_path = 'sample_image.jpg'

# %% [markdown]
# ## Part 1: Histogram
#
# Understanding the concept of image histogram
#
# **Exercise 1:** Calculate and display the histogram of an image

# %%
def calculate_and_display_histogram(image_path):
    """计算并图形化展示图像各颜色通道的直方图
    Calculate and graphically display histograms for each color channel of an image"""

    # 使用 imread 读取图像，默认以 BGR 顺序加载
    # Use imread to read the image, which loads it in BGR order by default
    img = cv2.imread(image_path)
    
    # 设置直方图线段的颜色
    # Set the line colors for the histogram
    # 解释：'b' 代表蓝色，'g' 代表绿色，'r' 代表红色，用于让曲线颜色与通道含义对应
    # Explanation: 'b' for Blue, 'g' for Green, 'r' for Red, so curve colors match their channel meanings
    colors = ('b', 'g', 'r')
    
    # 设置各通道的人类可读标签，用于直方图的图例显示
    # Set human-readable labels for each channel, used for the histogram legend
    channel_names = ('Blue', 'Green', 'Red')
    
    # 准备一个 12x5 英寸的绘图窗口
    # Prepare a 12x5 inch plotting window
    # 解释：figsize=(宽, 高)，12 英寸宽是为了并排放两张图不拥挤，5 英寸高适合直方图的纵横比
    # Explanation: figsize=(width, height), 12 inches wide for two side-by-side plots, 5 inches tall suits histogram aspect ratio
    plt.figure(figsize=(12, 5))
    
    # 定位到 1x2 布局的第一个子图以展示原图
    # Locate the first subplot of the 1x2 layout to display the original image
    # 解释：(1, 2, 1) 表示把画布分成 1 行 2 列，当前激活第 1 个格子
    # Explanation: (1, 2, 1) means split canvas into 1 row, 2 columns, and activate the 1st cell
    plt.subplot(1, 2, 1)

    # 转换通道顺序：BGR -> RGB，以适配 Matplotlib 的显示标准
    # Convert channel order: BGR -> RGB to fit Matplotlib display standards
    # 原因：OpenCV 使用 BGR 存储，但大部分绘图库使用 RGB 顺序
    # Reason: OpenCV uses BGR storage, but most plotting libraries use RGB order
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # 在界面上展示转换后的全彩原图
    # Display the converted full-color original image on the interface
    # 解释：imshow 将多维数组渲染为图像，用于直观验证
    # Explanation: imshow renders multidimensional arrays as images for visual verification
    plt.imshow(img_rgb)

    # 为当前的子图设定一个人类可读的标题
    # Set a human-readable title for the current subplot
    plt.title('Original Image')

    # 关闭坐标轴显示，去除冗余的像素坐标刻度
    # Turn off axis display, removing redundant pixel coordinate scales
    # 原因：对于普通图片预览，坐标轴通常会干扰视觉重点
    # Reason: For standard image previews, axes often distract from visual focus
    plt.axis('off')
    
    # 定位到 1x2 布局的第二个子图以绘制直方图
    # Locate the second subplot of the 1x2 layout to draw the histogram
    # 解释：(1, 2, 2) 表示 1 行 2 列中的第 2 个格子
    # Explanation: (1, 2, 2) means the 2nd cell in a 1-row, 2-column grid
    plt.subplot(1, 2, 2)

    # 分别计算并绘制三个颜色通道的强度分布
    # Calculate and plot intensity distributions for the three color channels respectively
    for i, (color, name) in enumerate(zip(colors, channel_names)):
        # 调用 calcHist 计算 256 个强度等级的分布
        # Call calcHist to calculate distribution of 256 intensity levels
        # 参数：[img] 将原图包在列表里传入（API 支持同时处理多张图），
        #       [i] 指定计算第几个通道（0=蓝, 1=绿, 2=红），
        #       None 表示不使用掩码（即统计整幅图而非局部区域），
        #       [256] 表示将像素值分成 256 个柱子来统计（每个亮度值一个柱子），
        #       [0, 256] 限定只统计亮度在 0~255 之间的像素
        # Parameters: [img] wraps image in a list (API supports multiple images at once),
        #       [i] specifies which channel to compute (0=Blue, 1=Green, 2=Red),
        #       None means no mask (count all pixels, not just a sub-region),
        #       [256] splits pixel values into 256 bins (one bin per intensity level),
        #       [0, 256] only counts pixels with intensity between 0 and 255
        hist = cv2.calcHist([img], [i], None, [256], [0, 256])

        # 使用对应通道的颜色绘制曲线
        # Plot the curve using the color of the corresponding channel
        plt.plot(hist, color=color, label=name)
    
    # 设置图表的标题，说明其展示内容为颜色直方图
    # Set the chart title, indicating it shows the color histogram
    plt.title('Color Histogram')

    # 为 X 轴添加标签，说明其代表像素从 0 到 255 的强度
    # Add a label for the X-axis, representing pixel intensity from 0 to 255
    plt.xlabel('Pixel Intensity (0-255)')

    # 为 Y 轴添加标签，说明其代表像素出现的频率
    # Add a label for the Y-axis, representing the frequency of pixel occurrence
    plt.ylabel('Frequency')

    # 限制 X 轴的范围在 0 到 256 之间
    # Limit the X-axis range between 0 and 256
    # 原因：8 位图像的像素亮度只在 0（纯黑）到 255（纯白）之间，256 是右边界的开区间
    # Reason: 8-bit pixel intensities range from 0 (pure black) to 255 (pure white), 256 is the open right boundary
    plt.xlim([0, 256])

    # 开启图例显示，帮助识别不同颜色的曲线对应的通道
    # Enable legend display to help identify which channel each colored curve represents
    plt.legend()

    # 添加辅助网格线，透明度设为 0.3 以免喧宾夺主
    # Add auxiliary grid lines with alpha set to 0.3 to avoid being distracting
    # 解释：alpha=0.3 让网格线呈半透明状态，便于读数又不遮挡曲线
    # Explanation: alpha=0.3 makes grid lines semi-transparent, aiding value reading without blocking curves
    plt.grid(True, alpha=0.3)
    
    # 使用 tight_layout 自动调整各组件间距，确保不重叠
    # Use tight_layout to automatically adjust component spacing to ensure no overlaps
    plt.tight_layout()

    # 将生成的完整图表呈现给用户
    # Render and present the complete generated chart to the user
    plt.show()
    
    # 计算所有通道的数据并返回列表
    # Calculate data for all channels and return a list
    img_histogram = [cv2.calcHist([img], [i], None, [256], [0, 256]) for i in range(3)]
    return img_histogram

# %%
# 执行练习 1：计算并展示样图的颜色直方图
# Execute Exercise 1: Calculate and display the color histogram of the sample image
histogram = calculate_and_display_histogram(image_path)
print(f'Number of channels: {len(histogram)}')
# Out:
# Number of channels: 3

# %% [markdown]
# ## Part 2: Image Thresholding
#
# Understanding different image thresholding techniques:
# - Global Thresholding
# - Adaptive Mean Thresholding
# - Adaptive Gaussian Thresholding
#
# **Exercise 2:** Convert an image from RGB to Grayscale and then apply global(binary),
# adaptive mean and adaptive gaussian thresholding and display the results.

# %%
def convert_to_grayscale_and_apply_threshold(image_path):
    """将图像转换为灰度并演示各种阈值分割算法
    Convert image to grayscale and demonstrate various threshold segmentation algorithms"""

    # 读取样图数据
    # Read sample image data
    img = cv2.imread(image_path)

    # 转换为单通道灰度图，这是阈值运算的标准输入格式
    # Convert to single-channel grayscale, the standard input format for thresholding
    # 原因：阈值比较本质上是亮度比较，不需要颜色信息
    # Reason: Threshold comparison is essentially brightness comparison, color info not needed
    # Gray = 0.114 × B + 0.587 × G + 0.299 × R
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # 方法 A：固定全局阈值二值化
    # Method A: Fixed Global Threshold Binarization
    # 解释：对整幅图使用同一条分界线，适合前景和背景亮度差异明显的简单场景
    # Explanation: Apply one single cutoff to the entire image, suitable for simple scenes with clear foreground-background contrast
    # 参数：127 是明暗分界线（亮度 > 127 的像素变白，≤ 127 的变黑），
    #       255 是"变白"后赋予的像素值（纯白），
    #       THRESH_BINARY 表示输出只有纯黑(0)和纯白(255)两种结果
    # Parameters: 127 is the brightness cutoff (pixels > 127 become white, ≤ 127 become black),
    #       255 is the value assigned to "white" pixels (pure white),
    #       THRESH_BINARY means output has only two values: black(0) and white(255)
    _, global_thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    
    # 方法 B：自适应均值阈值化
    # Method B: Adaptive Mean Thresholding
    # 解释：不再用一条全局分界线，而是为每个像素单独计算局部阈值 = 邻域均值 - C
    # Explanation: Instead of one global cutoff, compute a local threshold for each pixel = neighborhood mean - C
    # 原因：能有效应对由于光照渐变产生的不均匀明暗背景
    # Reason: Effectively handles non-uniform light/dark backgrounds caused by gradual lighting changes
    # 参数：255 是超过局部阈值后赋予的像素值（纯白），
    #       ADAPTIVE_THRESH_MEAN_C 表示局部阈值由邻域内所有像素的算术平均值决定，
    #       THRESH_BINARY 表示输出只有黑白两种结果，
    #       11 是邻域窗口的边长（以每个像素为中心，取 11×11 的方形区域来计算平均值），
    #       2 是从平均值中减去的微调常数（值越大，越多像素被判定为黑色）
    # Parameters: 255 is the value assigned to pixels exceeding the local threshold (pure white),
    #       ADAPTIVE_THRESH_MEAN_C means local threshold is the arithmetic mean of the neighborhood,
    #       THRESH_BINARY means output is binary (black or white only),
    #       11 is the neighborhood window side length (an 11x11 square centered on each pixel for computing mean),
    #       2 is a fine-tuning constant subtracted from the mean (larger value = more pixels classified as black)
    adaptive_mean_thresh = cv2.adaptiveThreshold(
        gray, 255,
        cv2.ADAPTIVE_THRESH_MEAN_C,
        cv2.THRESH_BINARY,
        11, 2
    )
    
    # 方法 C：自适应高斯阈值化
    # Method C: Adaptive Gaussian Thresholding
    # 解释：与均值法类似，但局部阈值 = 邻域的高斯加权均值 - C（靠近中心的像素权重更高）
    # Explanation: Similar to mean method, but local threshold = Gaussian-weighted mean of neighborhood - C (pixels closer to center carry higher weight)
    # 原因：高斯加权让中心像素影响更大，结果比均值法更平滑，边缘更细腻
    # Reason: Gaussian weighting gives center pixels more influence, producing smoother results with finer edges than mean method
    # 参数：255 是超过局部阈值后赋予的像素值（纯白），
    #       ADAPTIVE_THRESH_GAUSSIAN_C 表示局部阈值由高斯加权均值决定（非等权平均），
    #       THRESH_BINARY 表示输出只有黑白两种结果，
    #       11 是邻域窗口的边长（取 11×11 区域，但中心像素权重最高，边缘权重递减），
    #       2 是从高斯加权均值中减去的微调常数（作用与均值法中的 C 相同）
    # Parameters: 255 is the value assigned to pixels exceeding the local threshold (pure white),
    #       ADAPTIVE_THRESH_GAUSSIAN_C means local threshold is a Gaussian-weighted mean (not equal-weight),
    #       THRESH_BINARY means output is binary (black or white only),
    #       11 is the neighborhood window side length (11x11 area, but center pixel has highest weight, edges taper off),
    #       2 is a fine-tuning constant subtracted from the Gaussian-weighted mean (same role as C in mean method)
    adaptive_gaussian_thresh = cv2.adaptiveThreshold(
        gray, 255,
        cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
        cv2.THRESH_BINARY,
        11, 2
    )
    
    # 布局 2x2 的多算法对比画廊
    # Lay out a 2x2 multi-algorithm comparison gallery
    # 解释：subplots(2, 2) 把画布分成 2 行 2 列共 4 个格子，figsize=(12, 10) 设定画布为 12 英寸宽、10 英寸高
    # Explanation: subplots(2, 2) splits canvas into 2 rows, 2 columns (4 cells), figsize=(12, 10) sets canvas to 12 inches wide, 10 inches tall
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))
    
    # 在布局的 [0,0]（左上角）格展示原灰度图
    # Show original grayscale in [0,0] (top-left) cell
    # 解释：cmap='gray' 告诉 Matplotlib 用灰度色板渲染，否则单通道数据会显示为彩色热力图
    # Explanation: cmap='gray' tells Matplotlib to render with grayscale palette, otherwise single-channel data shows as a colored heatmap
    axes[0, 0].imshow(gray, cmap='gray')

    # 为左上角子图设置描述性标题
    # Set descriptive title for the top-left subplot
    axes[0, 0].set_title('Original Grayscale')

    # 关闭该区域的坐标系统显示
    # Turn off the coordinate system display for this area
    axes[0, 0].axis('off')
    
    # 在 [0,1]（右上角）展示执行全局方案后的结果
    # Show global scheme results in [0,1] (top-right)
    # 解释：全局阈值用同一个标准处理整幅图，光照不均时容易出现大面积误判
    # Explanation: Global threshold applies one standard to the whole image, prone to large misclassified areas under uneven lighting
    axes[0, 1].imshow(global_thresh, cmap='gray')
    axes[0, 1].set_title('Global Thresholding')
    axes[0, 1].axis('off')
    
    # 在 [1,0]（左下角）展示自适应均值方案
    # Show adaptive mean scheme in [1,0] (bottom-left)
    # 解释：该算法对局部照度变化有较好的鲁棒性
    # Explanation: This algorithm is robust against local illumination changes
    axes[1, 0].imshow(adaptive_mean_thresh, cmap='gray')
    axes[1, 0].set_title('Adaptive Mean Thresholding')
    axes[1, 0].axis('off')
    
    # 在 [1,1]（右下角）展示自适应高斯方案
    # Show adaptive gaussian scheme in [1,1] (bottom-right)
    # 解释：高斯加权比等权平均产生更平滑的边缘，适合细节丰富的图像
    # Explanation: Gaussian weighting produces smoother edges than equal-weight averaging, suitable for detail-rich images
    axes[1, 1].imshow(adaptive_gaussian_thresh, cmap='gray')
    axes[1, 1].set_title('Adaptive Gaussian Thresholding')
    axes[1, 1].axis('off')
    
    # 调整布局并弹出图形界面
    # Adjust layout and pop up graphics interface
    plt.tight_layout()
    plt.show()
    
    # 返回三种阈值分割的结果，依次为：全局、自适应均值、自适应高斯
    # Return results of three thresholding methods: Global, Adaptive Mean, Adaptive Gaussian
    return global_thresh, adaptive_mean_thresh, adaptive_gaussian_thresh

# %%
# 执行练习 2：对样图进行灰度转换并应用三种阈值分割算法
# Execute Exercise 2: Convert sample to grayscale and apply three thresholding algorithms
global_thresh, adaptive_mean, adaptive_gaussian = convert_to_grayscale_and_apply_threshold(image_path)

# %% [markdown]
# ## Part 3: Morphological Operations
#
# Understanding different morphological operations:
# - Erosion: Removes pixels from object boundaries
# - Dilation: Adds pixels to object boundaries
# - Opening: Erosion followed by Dilation (removes small noise)
# - Closing: Dilation followed by Erosion (fills small holes)
#
# **Exercise 3:** Convert an image to grayscale and perform each erosion, dilation,
# opening and closing operations. Display the results.

# %%
def process_image(image_path, kernel_size):
    """在灰度图像上执行基本形态学操作（膨胀、腐蚀、开运算、闭运算）
    Perform basic morphological operations (Dilation, Erosion, Opening, Closing) on grayscale images"""

    # 读取图像并转换为灰度图
    # Read image and convert to grayscale
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # 定义邻域操作的结构元素（Kernel）
    # Define the structuring element for neighborhood operations (Kernel)
    # 解释：kernel 是一个全 1 的正方形矩阵，像一个滑动窗口在图像上逐像素移动，
    #       窗口越大（kernel_size 越大），每次操作涉及的邻域范围越广，效果越明显
    # Explanation: kernel is an all-ones square matrix that slides across the image pixel by pixel,
    #       the larger the window (kernel_size), the wider the neighborhood involved, the stronger the effect
    # 参数：(kernel_size, kernel_size) 决定窗口的宽高（如 5×5 表示看周围 5 格范围），
    #       np.uint8 指定数据类型为 8 位无符号整数（形态学运算要求）
    # Parameters: (kernel_size, kernel_size) sets window width and height (e.g. 5x5 means looking at 5-pixel radius),
    #       np.uint8 specifies data type as 8-bit unsigned integer (required by morphological operations)
    kernel = np.ones((kernel_size, kernel_size), np.uint8)
    
    # 膨胀操作：扩展图像中的亮色区域
    # Dilation: Expand bright regions in the image
    # 解释：取窗口范围内的最大亮度值赋给中心像素——亮色区域因此向外扩张，图像整体变亮
    # Explanation: Assign the maximum brightness within the window to the center pixel — bright regions expand outward, image becomes brighter overall
    # 参数：gray 是待处理的灰度图，
    #       kernel 是滑动窗口（决定扩张的范围），
    #       iterations=1 表示只执行一轮膨胀（增大此值则扩张效果叠加）
    # Parameters: gray is the grayscale image to process,
    #       kernel is the sliding window (determines expansion range),
    #       iterations=1 means apply dilation once (increase to stack the expansion effect)
    dilated_img = cv2.dilate(gray, kernel, iterations=1)
    
    # 腐蚀操作：收缩图像中的亮色区域
    # Erosion: Shrink bright regions in the image
    # 解释：取窗口范围内的最小亮度值赋给中心像素——暗色区域因此向外扩张，图像整体变暗
    # Explanation: Assign the minimum brightness within the window to the center pixel — dark regions expand outward, image becomes darker overall
    # 参数：gray 是待处理的灰度图，
    #       kernel 是滑动窗口（决定收缩的范围），
    #       iterations=1 表示只执行一轮腐蚀（增大此值则收缩更深）
    # Parameters: gray is the grayscale image to process,
    #       kernel is the sliding window (determines shrinkage range),
    #       iterations=1 means apply erosion once (increase to deepen the shrinkage effect)
    eroded_img = cv2.erode(gray, kernel, iterations=1)
    
    # 开运算：先腐蚀后膨胀
    # Opening: Erosion followed by Dilation
    # 解释：先腐蚀去掉小的亮色噪点，再膨胀恢复主体亮度——小亮斑消失了，但主体基本不变
    # Explanation: Erosion first removes small bright noise, then dilation restores main body brightness — small bright spots disappear while main body stays roughly the same
    # 参数：cv2.MORPH_OPEN 告诉 OpenCV 按"先腐蚀后膨胀"的顺序组合执行
    # Parameters: cv2.MORPH_OPEN tells OpenCV to combine operations in "erosion then dilation" order
    opened_img = cv2.morphologyEx(gray, cv2.MORPH_OPEN, kernel)
    
    # 闭运算：先膨胀后腐蚀
    # Closing: Dilation followed by Erosion
    # 解释：先膨胀填充小的暗色孔洞，再腐蚀恢复主体亮度——小暗斑被填上了，但主体基本不变
    # Explanation: Dilation first fills small dark holes, then erosion restores main body brightness — small dark spots get filled while main body stays roughly the same
    # 参数：cv2.MORPH_CLOSE 告诉 OpenCV 按"先膨胀后腐蚀"的顺序组合执行
    # Parameters: cv2.MORPH_CLOSE tells OpenCV to combine operations in "dilation then erosion" order
    closed_img = cv2.morphologyEx(gray, cv2.MORPH_CLOSE, kernel)
    
    # 创建 2x3 的多项对比展示面板
    # Create a 2x3 multi-item comparison panel
    # 解释：subplots(2, 3) 把画布分成 2 行 3 列共 6 个格子，用 5 个展示图像，1 个留空
    # Explanation: subplots(2, 3) splits canvas into 2 rows, 3 columns (6 cells), 5 for images, 1 left empty
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    
    # 在第一行第一列配置原灰度预览图
    # Configure original grayscale preview in row 0, column 0
    # 解释：这是对比实验的原始基准，方便与处理结果进行视觉对照
    # Explanation: This is the original baseline for comparison, allowing visual contrast with processed results
    axes[0, 0].imshow(gray, cmap='gray')
    axes[0, 0].set_title('Original Grayscale')
    axes[0, 0].axis('off')
    
    # 配置第一行第二列：展示膨胀扩张效果
    # Configure row 0, column 1: show dilation expansion effect
    # 解释：对比原图可以看到亮色区域向外扩大，图像整体更亮
    # Explanation: Compared to original, bright regions have expanded outward, image appears brighter overall
    axes[0, 1].imshow(dilated_img, cmap='gray')
    axes[0, 1].set_title('Dilation (Expand Bright)')
    axes[0, 1].axis('off')
    
    # 配置第一行第三列：展示腐蚀收缩效果
    # Configure row 0, column 2: show erosion shrinking effect
    # 解释：对比原图可以看到暗色区域向外扩大，图像整体更暗
    # Explanation: Compared to original, dark regions have expanded outward, image appears darker overall
    axes[0, 2].imshow(eroded_img, cmap='gray')
    axes[0, 2].set_title('Erosion (Expand Dark)')
    axes[0, 2].axis('off')
    
    # 配置第二行第一列：展示开运算处理结果
    # Configure row 1, column 0: show opening operation results
    # 解释：小的亮色噪点被去除了，但主体亮度和轮廓基本保持不变
    # Explanation: Small bright noise spots have been removed, but main body brightness and contour remain roughly unchanged
    axes[1, 0].imshow(opened_img, cmap='gray')
    axes[1, 0].set_title('Opening (Remove Bright Noise)')
    axes[1, 0].axis('off')
    
    # 配置第二行第二列：展示闭运算处理结果
    # Configure row 1, column 1: show closing operation results
    # 解释：物体内部的小暗斑被填上了，但主体轮廓基本保持不变
    # Explanation: Small dark spots inside objects have been filled, but main contour remains roughly unchanged
    axes[1, 1].imshow(closed_img, cmap='gray')
    axes[1, 1].set_title('Closing (Fill Dark Holes)')
    axes[1, 1].axis('off')
    
    # 隐藏第二行第三列的空白格子
    # Hide the empty cell in row 1, column 2
    axes[1, 2].axis('off')
    
    # 提交布局并绘制
    # Submit layout and draw
    plt.tight_layout()
    plt.show()
    
    # 返回四种形态学操作的结果，依次为：膨胀、腐蚀、开运算、闭运算
    # Return results of four morphological operations: Dilation, Erosion, Opening, Closing
    return dilated_img, eroded_img, opened_img, closed_img

# %%
# 执行练习 3：以 5x5 核对样图执行四种形态学操作
# Execute Exercise 3: Perform four morphological operations on sample with 5x5 kernel
dilated, eroded, opened, closed = process_image(image_path, kernel_size=5)
