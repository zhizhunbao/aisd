# %% [markdown]
# ## **CST8508 Machine Vision - Lab 2 - Image Processing with OpenCV**

# %% [markdown]
# **Objective:**
# To provide students with practical experience in basic image processing techniques using OpenCV, reinforcing concepts from the initial lectures.
#
# **Materials Required:**
#
# Computers with Python and OpenCV installed or Google Colab on web browser
#
# Sample images for processing
#
# **Lab Duration:** 2 hours

# %%
#### code block for defining path of image to be used throughout the exercise ####

# %% [markdown]
# **Part 1: Histogram**
# Understanding the concept of image histogram
#
# **Exercise 1:**
# Calculate and display the histogram of an image

# %%
def calculate_and_display_histogram(image_path):
    # implementation here
    return img_histogram

# %% [markdown]
# **Part 2: Image Thresholding**
#
# Understanding different image thresholding techniques - Global Thresholding, Adaptive Mean Threshoding, Adaptive gaussian Threshoding
#
# **Exercise 2:** Convert an image from RGB to Grayscale and then apply global(binary), adaptive mean and adaptive gaussian thresholding and display the results.

# %%
def convert_to_grayscale_and_apply_threshold(image_path):
    # implementation here
    return global_thresh, adaptive_mean_thresh, adaptive_gaussian_thresh

# %% [markdown]
# **Part 3: Morphological Operatiions**
#
# Understanding different morphological operations like erosion, dilation, opening and closing.
#
# **Exercise 3: Convert an image to gray scale and perform each erosion, dilation, opening and closing operations. Display the results.**

# %%
def process_image(image_path, kernel_size):
    # 1. DEFINE kernel as a matrix of ones with size (kernel_size x kernel_size)
    # 2. Perform Dilation
    # 3. Perform Erosion
    # 4. Perform Opening (Erosion followed by Dilation)
    # 5. Perform Closing (Dilation followed by Erosion)
    return dilated_img, eroded_img, opened_img, closed_img
